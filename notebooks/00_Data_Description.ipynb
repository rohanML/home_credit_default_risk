# %% [markdown]
# # Data

# %% [markdown]
# Home credit wants to unlock the full potential of their data using Machine Learning. They have shared the data about
#
# 1. **Application and applicant's details**
# 2. **Her loan history, if any, with Home Credit**
# 3. **Her loan history, if any, with other institution received from Credit Bureau**
#
# All this information is avaialbe in 7 files.
#
# 1. **application_{train|test}.csv** - The main file with information about loan and loan applicants. Each row represents an unique loan and whether it was repaid or defaulted on.    <br />
#   <br />
# 2. **previous_application.csv** - All previous applications for Home Credit loans of clients who have loans in our sample. Each row is one prevoius application.      <br />
#   <br />
# 3. **POS_CASH_balance.csv** - Monthly balance snapshots of previous POS (point of sales) and cash loans that the applicant had with Home Credit.This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample.  <br />
#   i.e. the table has (# of loans in sample * # of relative previous credits * # of months in which we have some history observable for the previous credits) rows.    <br />
#   <br />
# 4. **credit_card_balance.csv** - Monthly balance snapshots of previous credit cards that the applicant has with Home Credit. This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample.  <br />
# i.e. the table has (# of loans in sample * # of relative previous credit cards * # of months where we have some history observable for the previous credit card) rows.      <br />
#   <br />
# 5. **installments_payments.csv** - Repayment history for the previously disbursed credits in Home Credit related to the loans in our sample. There is a) one row for every payment that was made plus b) one row each for missed payment. One row is equivalent to one payment of one installment OR one installment corresponding to one payment of one previous Home Credit credit related to loans in our sample.  <br />
#   <br />
# 6. **bureau.csv** - All client's previous credits provided by other financial institutions that were reported to Credit Bureau (for clients who have a loan in our sample). For every loan in our sample, there are as many rows as number of credits the client had in Credit Bureau before the application date.  <br />
#   <br />
#
# 7. **bureau_balance.csv** - Monthly balances of previous credits in Credit Bureau. This table has one row for each month of history of every previous credit reported to Credit Bureau – i.e the table has (#loans in sample * # of relative previous credits * # of months where we have some history observable for the previous credits) rows.  <br />

# %% [markdown]
# We also have data dictionary with the decription of each variable. Let us expore it to get a broad view of data.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

dictionary = pd.read_csv('../docs/data dictionary/HomeCredit_columns_description.csv')

# %%
dictionary.head()
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
#
#                                                                                                                                                                                    Description  \
# 0                                                                                                                                                                     ID of loan in our sample
# 1  Target variable (1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 0 - all other cases)
# ...

# %%
dictionary.drop('Unnamed: 0',axis=1,inplace=True)
dictionary.shape
# Out:
# (219, 4)

# %%
dictionary.groupby('Table').Row.agg('count')
# Out:
# Table
# POS_CASH_balance.csv              8
# application_{train|test}.csv    122
# bureau.csv                       17
# bureau_balance.csv                3
# credit_card_balance.csv          23
# installments_payments.csv         8
# previous_application.csv         38
# Name: Row, dtype: int64

# %% [markdown]
# We have 219  variables in total. Majority of the variables are from current application & previous application.

# %%
dictionary
# Out:
#                             Table                           Row  \
# 0    application_{train|test}.csv                    SK_ID_CURR
# 1    application_{train|test}.csv                        TARGET
# 2    application_{train|test}.csv            NAME_CONTRACT_TYPE
# 3    application_{train|test}.csv                   CODE_GENDER
# 4    application_{train|test}.csv                  FLAG_OWN_CAR
# 5    application_{train|test}.csv               FLAG_OWN_REALTY
# 6    application_{train|test}.csv                  CNT_CHILDREN
# 7    application_{train|test}.csv              AMT_INCOME_TOTAL
# 8    application_{train|test}.csv                    AMT_CREDIT
# 9    application_{train|test}.csv                   AMT_ANNUITY
# 10   application_{train|test}.csv               AMT_GOODS_PRICE
# 11   application_{train|test}.csv               NAME_TYPE_SUITE
# 12   application_{train|test}.csv              NAME_INCOME_TYPE
# 13   application_{train|test}.csv           NAME_EDUCATION_TYPE
# ...

# %% [markdown]
# source : https://www.kaggle.com/c/home-credit-default-risk/data

# %% [markdown]
# A kaggler has kindly provided some insights about domain knowledge at
# https://www.kaggle.com/c/home-credit-default-risk/discussion/63032
